# %%
import tkinter as tk
from tkinter import messagebox
import os
import platform
import subprocess

def shutdown(delay=0):
    """Shutdown the computer with an optional delay."""
    if platform.system() == "Windows":
        os.system(f"shutdown /s /f /t {delay}")
    elif platform.system() == "Linux" or platform.system() == "Darwin":  # macOS
        os.system(f"sudo shutdown -h +{delay}")

def restart(delay=0):
    """Restart the computer with an optional delay."""
    if platform.system() == "Windows":
        os.system(f"shutdown /r /f /t {delay}")
    elif platform.system() == "Linux" or platform.system() == "Darwin":  # macOS
        os.system(f"sudo shutdown -r +{delay}")

def hibernate():
    """Put the computer into hibernation."""
    if platform.system() == "Windows":
        os.system("shutdown /h")
    elif platform.system() == "Linux":
        os.system("systemctl hibernate")
    elif platform.system() == "Darwin":  # macOS
        os.system("pmset hibernate")

def sleep():
    """Put the computer into sleep mode."""
    if platform.system() == "Windows":
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])
    elif platform.system() == "Linux":
        os.system("systemctl suspend")
    elif platform.system() == "Darwin":  # macOS
        os.system("pmset sleepnow")

def abort():
    """Abort a scheduled shutdown or restart."""
    if platform.system() == "Windows":
        os.system("shutdown /a")
    elif platform.system() == "Linux" or platform.system() == "Darwin":  # macOS
        os.system("sudo shutdown -c")

def on_closing():
    if messagebox.askokcancel("Quit", "Do you want to quit?"):
        root.destroy()

def create_round_window(root):
    root.overrideredirect(1)  # Remove window decorations
    root.geometry("400x400+100+100")  # Set window size and position
    root.wm_attributes("-transparentcolor", "white")  # Make white color transparent

    canvas = tk.Canvas(root, width=400, height=400, bd=0, highlightthickness=0)
    canvas.pack()

    # Draw a round background
    canvas.create_oval(0, 0, 400, 400, fill="lightblue", outline="lightblue")

    # Create a frame within the round window
    frame = tk.Frame(root, bg="lightblue")
    frame.place(relx=0.5, rely=0.5, anchor="center")

    return canvas, frame

def main():
    global root
    root = tk.Tk()
    canvas, frame = create_round_window(root)

    # Create buttons for each action
    shutdown_button = tk.Button(frame, text="Shutdown", command=lambda: shutdown(0), width=15)
    restart_button = tk.Button(frame, text="Restart", command=lambda: restart(0), width=15)
    hibernate_button = tk.Button(frame, text="Hibernate", command=hibernate, width=15)
    sleep_button = tk.Button(frame, text="Sleep", command=sleep, width=15)
    abort_button = tk.Button(frame, text="Abort", command=abort, width=15)

    shutdown_button.grid(row=0, column=0, pady=10)
    restart_button.grid(row=1, column=0, pady=10)
    hibernate_button.grid(row=2, column=0, pady=10)
    sleep_button.grid(row=3, column=0, pady=10)
    abort_button.grid(row=4, column=0, pady=10)

    # Custom close button
    close_button = tk.Button(root, text="X", command=on_closing, bg="red", fg="white", relief="flat")
    close_button.place(x=370, y=10)

    # Optional: minimize and maximize buttons
    minimize_button = tk.Button(root, text="_", command=lambda: root.iconify(), bg="yellow", fg="black", relief="flat")
    minimize_button.place(x=340, y=10)

    maximize_button = tk.Button(root, text="□", command=lambda: root.state('zoomed'), bg="green", fg="black", relief="flat")
    maximize_button.place(x=310, y=10)

    root.protocol("WM_DELETE_WINDOW", on_closing)
    root.mainloop()

if __name__ == "__main__":
    main()

# %%
import tkinter as tk
from tkinter import messagebox
import os
import platform
import subprocess

def shutdown(delay=0):
    """Shutdown the computer with an optional delay."""
    os.system(f"shutdown /s /f /t {delay}")

def restart(delay=0):
    """Restart the computer with an optional delay."""
    os.system(f"shutdown /r /f /t {delay}")

def hibernate():
    """Put the computer into hibernation."""
    os.system("shutdown /h")

def sleep():
    """Put the computer into sleep mode."""
    subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

def abort():
    """Abort a scheduled shutdown or restart."""
    os.system("shutdown /a")

def on_closing():
    if messagebox.askokcancel("Quit", "Do you want to quit?"):
        root.destroy()

def create_black_window(root):
    root.overrideredirect(1)  # Remove window decorations
    root.geometry("400x400+100+100")  # Set window size and position
    root.configure(bg="black")

    canvas = tk.Canvas(root, width=400, height=400, bg="black", bd=0, highlightthickness=0)
    canvas.pack()

    return canvas

def create_round_button(parent, text, command, x, y):
    button = tk.Button(parent, text=text, command=command, width=10, height=2, 
                       bg="gray", fg="white", relief="flat", font=("Arial", 12, "bold"))
    button.place(x=x, y=y)
    return button

def main():
    global root
    root = tk.Tk()
    canvas = create_black_window(root)

    # Create round buttons for each action
    create_round_button(canvas, "Shutdown", lambda: shutdown(0), 150, 50)
    create_round_button(canvas, "Restart", lambda: restart(0), 150, 110)
    create_round_button(canvas, "Hibernate", hibernate, 150, 170)
    create_round_button(canvas, "Sleep", sleep, 150, 230)
    create_round_button(canvas, "Abort", abort, 150, 290)

    # Custom close button
    close_button = tk.Button(root, text="X", command=on_closing, bg="red", fg="white", relief="flat", font=("Arial", 10, "bold"))
    close_button.place(x=370, y=10)

    # Optional: minimize and maximize buttons
    minimize_button = tk.Button(root, text="_", command=lambda: root.iconify(), bg="yellow", fg="black", relief="flat", font=("Arial", 10, "bold"))
    minimize_button.place(x=340, y=10)

    maximize_button = tk.Button(root, text="□", command=lambda: root.state('zoomed'), bg="green", fg="black", relief="flat", font=("Arial", 10, "bold"))
    maximize_button.place(x=310, y=10)

    root.protocol("WM_DELETE_WINDOW", on_closing)
    root.mainloop()

if __name__ == "__main__":
    main()

# %%
import tkinter as tk
from tkinter import messagebox
import os
import subprocess

def shutdown(delay=0):
    """Shutdown the computer with an optional delay."""
    os.system(f"shutdown /s /f /t {delay}")

def restart(delay=0):
    """Restart the computer with an optional delay."""
    os.system(f"shutdown /r /f /t {delay}")

def hibernate():
    """Put the computer into hibernation."""
    os.system("shutdown /h")

def sleep():
    """Put the computer into sleep mode."""
    subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

def abort():
    """Abort a scheduled shutdown or restart."""
    os.system("shutdown /a")

def on_closing():
    if messagebox.askokcancel("Quit", "Do you want to quit?"):
        root.destroy()

def create_circle_button(parent, text, command, x, y):
    button = tk.Button(parent, text=text, command=command, width=10, height=2, 
                       bg="gray", fg="white", relief="flat", font=("Arial", 12, "bold"))
    button.place(x=x, y=y)
    return button

def main():
    global root
    root = tk.Tk()
    root.title("Power Control")
    root.geometry("400x400")
    root.configure(bg="black")

    # Create circle buttons for each action
    create_circle_button(root, "Shutdown", lambda: shutdown(0), 150, 50)
    create_circle_button(root, "Shutdown Delay", lambda: shutdown(60), 150, 110)
    create_circle_button(root, "Restart", lambda: restart(0), 150, 170)
    create_circle_button(root, "Restart Delay", lambda: restart(60), 150, 230)
    create_circle_button(root, "Hibernate", hibernate, 150, 290)
    create_circle_button(root, "Sleep", sleep, 150, 350)
    create_circle_button(root, "Abort", abort, 150, 410)

    # Window close button
    root.protocol("WM_DELETE_WINDOW", on_closing)
    root.mainloop()

if __name__ == "__main__":
    main()

# %%
import tkinter as tk
from tkinter import messagebox
import os
import subprocess

def shutdown(delay=0):
    """Shutdown the computer with an optional delay."""
    os.system(f"shutdown /s /f /t {delay}")

def restart(delay=0):
    """Restart the computer with an optional delay."""
    os.system(f"shutdown /r /f /t {delay}")

def hibernate():
    """Put the computer into hibernation."""
    os.system("shutdown /h")

def sleep():
    """Put the computer into sleep mode."""
    subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

def abort():
    """Abort a scheduled shutdown or restart."""
    os.system("shutdown /a")

def on_closing():
    if messagebox.askokcancel("Quit", "Do you want to quit?"):
        root.destroy()

def create_circle_button(parent, text, command, x, y):
    button = tk.Button(parent, text=text, command=command, width=10, height=2, 
                       bg="gray", fg="white", relief="flat", font=("Arial", 12, "bold"))
    button.place(x=x, y=y)
    return button

def main():
    global root
    root = tk.Tk()
    root.title("Power Control")
    root.geometry("400x500")
    root.configure(bg="black")

    # Create circle buttons for each action
    create_circle_button(root, "Shutdown", lambda: shutdown(0), 150, 50)
    create_circle_button(root, "Shutdown Delay", lambda: shutdown(60), 150, 110)
    create_circle_button(root, "Restart", lambda: restart(0), 150, 170)
    create_circle_button(root, "Restart Delay", lambda: restart(60), 150, 230)
    create_circle_button(root, "Hibernate", hibernate, 150, 290)
    create_circle_button(root, "Sleep", sleep, 150, 350)
    create_circle_button(root, "Abort", abort, 150, 410)

    # Window close button
    root.protocol("WM_DELETE_WINDOW", on_closing)
    root.mainloop()

if __name__ == "__main__":
    main()

# %%
# !pip install PyQt5

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QMessageBox
from PyQt5.QtGui import QPalette, QColor, QFont
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control")
        self.setGeometry(100, 100, 300, 400)

        # Set up the black theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Create a layout
        layout = QVBoxLayout()

        # Create buttons
        font = QFont('Arial', 12, QFont.Bold)
        button_style = "QPushButton {border-radius: 20px; padding: 10px;}"

        shutdown_button = QPushButton("Shutdown", self)
        shutdown_button.setFont(font)
        shutdown_button.setStyleSheet(button_style)
        shutdown_button.clicked.connect(lambda: self.shutdown(0))
        layout.addWidget(shutdown_button)

        shutdown_delay_button = QPushButton("Shutdown Delay", self)
        shutdown_delay_button.setFont(font)
        shutdown_delay_button.setStyleSheet(button_style)
        shutdown_delay_button.clicked.connect(lambda: self.shutdown(60))
        layout.addWidget(shutdown_delay_button)

        restart_button = QPushButton("Restart", self)
        restart_button.setFont(font)
        restart_button.setStyleSheet(button_style)
        restart_button.clicked.connect(lambda: self.restart(0))
        layout.addWidget(restart_button)

        restart_delay_button = QPushButton("Restart Delay", self)
        restart_delay_button.setFont(font)
        restart_delay_button.setStyleSheet(button_style)
        restart_delay_button.clicked.connect(lambda: self.restart(60))
        layout.addWidget(restart_delay_button)

        hibernate_button = QPushButton("Hibernate", self)
        hibernate_button.setFont(font)
        hibernate_button.setStyleSheet(button_style)
        hibernate_button.clicked.connect(self.hibernate)
        layout.addWidget(hibernate_button)

        sleep_button = QPushButton("Sleep", self)
        sleep_button.setFont(font)
        sleep_button.setStyleSheet(button_style)
        sleep_button.clicked.connect(self.sleep)
        layout.addWidget(sleep_button)

        abort_button = QPushButton("Abort", self)
        abort_button.setFont(font)
        abort_button.setStyleSheet(button_style)
        abort_button.clicked.connect(self.abort)
        layout.addWidget(abort_button)

        self.setLayout(layout)

    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\sanka\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QMessageBox, QLabel
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control")
        self.setGeometry(100, 100, 300, 450)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create a layout
        layout = QVBoxLayout()

        # Add logo
        logo_label = QLabel(self)
        pixmap = QPixmap("logo.png")
        logo_label.setPixmap(pixmap.scaled(100, 100, Qt.KeepAspectRatio))
        logo_label.setAlignment(Qt.AlignCenter)
        layout.addWidget(logo_label)

        # Create buttons
        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 40px;
            padding: 20px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        shutdown_button = QPushButton("Shutdown", self)
        shutdown_button.setFont(font)
        shutdown_button.setStyleSheet(button_style)
        shutdown_button.clicked.connect(lambda: self.shutdown(0))
        layout.addWidget(shutdown_button)

        shutdown_delay_button = QPushButton("Shutdown Delay", self)
        shutdown_delay_button.setFont(font)
        shutdown_delay_button.setStyleSheet(button_style)
        shutdown_delay_button.clicked.connect(lambda: self.shutdown(60))
        layout.addWidget(shutdown_delay_button)

        restart_button = QPushButton("Restart", self)
        restart_button.setFont(font)
        restart_button.setStyleSheet(button_style)
        restart_button.clicked.connect(lambda: self.restart(0))
        layout.addWidget(restart_button)

        restart_delay_button = QPushButton("Restart Delay", self)
        restart_delay_button.setFont(font)
        restart_delay_button.setStyleSheet(button_style)
        restart_delay_button.clicked.connect(lambda: self.restart(60))
        layout.addWidget(restart_delay_button)

        hibernate_button = QPushButton("Hibernate", self)
        hibernate_button.setFont(font)
        hibernate_button.setStyleSheet(button_style)
        hibernate_button.clicked.connect(self.hibernate)
        layout.addWidget(hibernate_button)

        sleep_button = QPushButton("Sleep", self)
        sleep_button.setFont(font)
        sleep_button.setStyleSheet(button_style)
        sleep_button.clicked.connect(self.sleep)
        layout.addWidget(sleep_button)

        abort_button = QPushButton("Abort", self)
        abort_button.setFont(font)
        abort_button.setStyleSheet(button_style)
        abort_button.clicked.connect(self.abort)
        layout.addWidget(abort_button)

        self.setLayout(layout)

    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QMessageBox, QLabel
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control and System Information")
        self.setGeometry(100, 100, 350, 700)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create a layout
        layout = QVBoxLayout()

        # Add logo
        logo_label = QLabel(self)
        pixmap = QPixmap("logo.png")
        logo_label.setPixmap(pixmap.scaled(100, 100, Qt.KeepAspectRatio))
        logo_label.setAlignment(Qt.AlignCenter)
        layout.addWidget(logo_label)

        # Create buttons for power control
        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 20px;
            padding: 15px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        # Power Control Buttons
        power_buttons = [
            ("Shutdown", lambda: self.shutdown(0)),
            ("Shutdown Delay", lambda: self.shutdown(60)),
            ("Restart", lambda: self.restart(0)),
            ("Restart Delay", lambda: self.restart(60)),
            ("Hibernate", self.hibernate),
            ("Sleep", self.sleep),
            ("Abort", self.abort)
        ]
        
        for text, func in power_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            layout.addWidget(button)

        # System Information Buttons
        info_buttons = [
            ("System Information", self.open_system_info),
            ("Device Manager", self.open_device_manager),
            ("System Properties", self.open_system_properties),
            ("Task Manager", self.open_task_manager),
            ("Command Line Info", self.open_command_line_info),
            ("DirectX Diagnostic", self.open_dxdiag)
        ]

        for text, func in info_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            layout.addWidget(button)

        self.setLayout(layout)

    # Power Control Functions
    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    # System Information Functions
    def open_system_info(self):
        subprocess.Popen("msinfo32")

    def open_device_manager(self):
        subprocess.Popen("devmgmt.msc")

    def open_system_properties(self):
        subprocess.Popen("sysdm.cpl")

    def open_task_manager(self):
        subprocess.Popen("taskmgr")

    def open_command_line_info(self):
        os.system("start cmd /k systeminfo")

    def open_dxdiag(self):
        subprocess.Popen("dxdiag")

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QMessageBox, QLabel
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control and System Information")
        self.setGeometry(100, 100, 350, 700)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create a layout
        layout = QVBoxLayout()

        # Add logo
        logo_label = QLabel(self)
        pixmap = QPixmap("logo.png")
        logo_label.setPixmap(pixmap.scaled(100, 100, Qt.KeepAspectRatio))
        logo_label.setAlignment(Qt.AlignCenter)
        layout.addWidget(logo_label)

        # Create buttons for power control
        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 20px;
            padding: 15px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        # Power Control Buttons
        power_buttons = [
            ("Shutdown", lambda: self.shutdown(0)),
            ("Shutdown Delay", lambda: self.shutdown(60)),
            ("Restart", lambda: self.restart(0)),
            ("Restart Delay", lambda: self.restart(60)),
            ("Hibernate", self.hibernate),
            ("Sleep", self.sleep),
            ("Abort", self.abort)
        ]
        
        for text, func in power_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            layout.addWidget(button)

        # System Information Buttons
        info_buttons = [
            ("System Information", self.open_system_info),
            ("Device Manager", self.open_device_manager),
            ("System Properties", self.open_system_properties),
            ("Task Manager", self.open_task_manager),
            ("Command Line Info", self.open_command_line_info),
            ("DirectX Diagnostic", self.open_dxdiag)
        ]

        for text, func in info_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            layout.addWidget(button)

        self.setLayout(layout)

    # Power Control Functions
    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    # System Information Functions
    def open_system_info(self):
        subprocess.Popen(["msinfo32"])

    def open_device_manager(self):
        subprocess.Popen(["devmgmt.msc"], shell=True)

    def open_system_properties(self):
        subprocess.Popen(["sysdm.cpl"], shell=True)

    def open_task_manager(self):
        subprocess.Popen(["taskmgr"], shell=True)

    def open_command_line_info(self):
        os.system("start cmd /k systeminfo")

    def open_dxdiag(self):
        subprocess.Popen(["dxdiag"])

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QMessageBox, QLabel, QGroupBox, QHBoxLayout
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control and System Information")
        self.setGeometry(100, 100, 400, 800)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create a main layout
        main_layout = QVBoxLayout()

        # Add logo
        logo_label = QLabel(self)
        pixmap = QPixmap("logo.png")
        logo_label.setPixmap(pixmap.scaled(100, 100, Qt.KeepAspectRatio))
        logo_label.setAlignment(Qt.AlignCenter)
        main_layout.addWidget(logo_label)

        # Create power control section
        power_group_box = QGroupBox("Power Control")
        power_layout = QVBoxLayout()
        
        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 20px;
            padding: 15px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        power_buttons = [
            ("Shutdown", lambda: self.shutdown(0)),
            ("Shutdown Delay", lambda: self.shutdown(60)),
            ("Restart", lambda: self.restart(0)),
            ("Restart Delay", lambda: self.restart(60)),
            ("Hibernate", self.hibernate),
            ("Sleep", self.sleep),
            ("Abort", self.abort)
        ]
        
        for text, func in power_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            power_layout.addWidget(button)

        power_group_box.setLayout(power_layout)
        main_layout.addWidget(power_group_box)

        # Create system information section
        info_group_box = QGroupBox("System Information")
        info_layout = QVBoxLayout()

        info_buttons = [
            ("System Information", self.open_system_info),
            ("Device Manager", self.open_device_manager),
            ("System Properties", self.open_system_properties),
            ("Task Manager", self.open_task_manager),
            ("Command Line Info", self.open_command_line_info),
            ("DirectX Diagnostic", self.open_dxdiag)
        ]

        for text, func in info_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            info_layout.addWidget(button)

        info_group_box.setLayout(info_layout)
        main_layout.addWidget(info_group_box)

        # Set main layout
        self.setLayout(main_layout)

    # Power Control Functions
    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    # System Information Functions
    def open_system_info(self):
        subprocess.Popen(["msinfo32"])

    def open_device_manager(self):
        subprocess.Popen(["devmgmt.msc"], shell=True)

    def open_system_properties(self):
        subprocess.Popen(["sysdm.cpl"], shell=True)

    def open_task_manager(self):
        subprocess.Popen(["taskmgr"], shell=True)

    def open_command_line_info(self):
        os.system("start cmd /k systeminfo")

    def open_dxdiag(self):
        subprocess.Popen(["dxdiag"])

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QHBoxLayout, QMessageBox, QLabel
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control and System Information")
        self.setGeometry(100, 100, 600, 500)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create the main horizontal layout
        main_layout = QHBoxLayout()

        # Create power options layout
        power_layout = QVBoxLayout()
        power_layout.addWidget(self.create_section_label("Power Options"))

        # Create system information layout
        info_layout = QVBoxLayout()
        info_layout.addWidget(self.create_section_label("System Information"))

        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 10px;
            padding: 15px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        # Power Control Buttons
        power_buttons = [
            ("Shutdown", lambda: self.shutdown(0)),
            ("Shutdown Delay", lambda: self.shutdown(60)),
            ("Restart", lambda: self.restart(0)),
            ("Restart Delay", lambda: self.restart(60)),
            ("Hibernate", self.hibernate),
            ("Sleep", self.sleep),
            ("Abort", self.abort)
        ]
        
        for text, func in power_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            power_layout.addWidget(button)

        # System Information Buttons
        info_buttons = [
            ("System Information", self.open_system_info),
            ("Device Manager", self.open_device_manager),
            ("System Properties", self.open_system_properties),
            ("Task Manager", self.open_task_manager),
            ("Command Line Info", self.open_command_line_info),
            ("DirectX Diagnostic", self.open_dxdiag)
        ]

        for text, func in info_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            info_layout.addWidget(button)

        # Add both layouts to the main horizontal layout
        main_layout.addLayout(power_layout)
        main_layout.addLayout(info_layout)

        # Set main layout
        self.setLayout(main_layout)

    def create_section_label(self, text):
        """Create a label for section titles."""
        label = QLabel(text)
        label.setFont(QFont('Arial', 14, QFont.Bold))
        label.setStyleSheet("color: white;")
        label.setAlignment(Qt.AlignCenter)
        return label

    # Power Control Functions
    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    # System Information Functions
    def open_system_info(self):
        subprocess.Popen(["msinfo32"])

    def open_device_manager(self):
        subprocess.Popen(["devmgmt.msc"], shell=True)

    def open_system_properties(self):
        subprocess.Popen(["sysdm.cpl"], shell=True)

    def open_task_manager(self):
        subprocess.Popen(["taskmgr"], shell=True)

    def open_command_line_info(self):
        os.system("start cmd /k systeminfo")

    def open_dxdiag(self):
        subprocess.Popen(["dxdiag"])

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QHBoxLayout, QMessageBox, QLabel, QLineEdit, QDialog, QDialogButtonBox
from PyQt5.QtGui import QPalette, QColor, QFont, QIcon, QPixmap
from PyQt5.QtCore import Qt
import os
import subprocess

class RunDialog(QDialog):
    def __init__(self):
        super().__init__()
        self.setWindowTitle("Run")
        self.setGeometry(100, 100, 400, 100)

        layout = QVBoxLayout()

        self.command_input = QLineEdit(self)
        self.command_input.setPlaceholderText("Type a command and press OK")
        layout.addWidget(self.command_input)

        buttons = QDialogButtonBox(QDialogButtonBox.Ok | QDialogButtonBox.Cancel, Qt.Horizontal, self)
        buttons.accepted.connect(self.run_command)
        buttons.rejected.connect(self.reject)
        layout.addWidget(buttons)

        self.setLayout(layout)

    def run_command(self):
        command = self.command_input.text()
        if command:
            os.system(command)
        self.accept()

class PowerControlApp(QWidget):
    def __init__(self):
        super().__init__()

        # Set up the window
        self.setWindowTitle("Power Control and System Information")
        self.setGeometry(100, 100, 700, 500)

        # Set up the black and white theme
        palette = QPalette()
        palette.setColor(QPalette.Window, QColor(0, 0, 0))
        palette.setColor(QPalette.Button, QColor(50, 50, 50))
        palette.setColor(QPalette.ButtonText, QColor(255, 255, 255))
        palette.setColor(QPalette.WindowText, QColor(255, 255, 255))
        self.setPalette(palette)

        # Set logo
        self.setWindowIcon(QIcon("logo.png"))

        # Create the main horizontal layout
        main_layout = QHBoxLayout()

        # Create system information layout
        info_layout = QVBoxLayout()
        info_layout.addWidget(self.create_section_label("System Information"))

        # Create power options layout
        power_layout = QVBoxLayout()
        power_layout.addWidget(self.create_section_label("Power Options"))

        font = QFont('Arial', 12, QFont.Bold)
        button_style = """
        QPushButton {
            border-radius: 10px;
            padding: 15px;
            background-color: #333;
            color: white;
        }
        QPushButton:pressed {
            background-color: #555;
        }
        """

        # System Information Buttons
        info_buttons = [
            ("System Information", self.open_system_info),
            ("Device Manager", self.open_device_manager),
            ("System Properties", self.open_system_properties),
            ("Task Manager", self.open_task_manager),
            ("Command Line Info", self.open_command_line_info),
            ("DirectX Diagnostic", self.open_dxdiag),
            ("Run Dialog", self.open_run_dialog)
        ]

        for text, func in info_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            info_layout.addWidget(button)

        # Power Control Buttons
        power_buttons = [
            ("Shutdown", lambda: self.shutdown(0)),
            ("Shutdown Delay", lambda: self.shutdown(60)),
            ("Restart", lambda: self.restart(0)),
            ("Restart Delay", lambda: self.restart(60)),
            ("Hibernate", self.hibernate),
            ("Sleep", self.sleep),
            ("Abort", self.abort)
        ]
        
        for text, func in power_buttons:
            button = QPushButton(text, self)
            button.setFont(font)
            button.setStyleSheet(button_style)
            button.clicked.connect(func)
            power_layout.addWidget(button)

        # Add both layouts to the main horizontal layout
        main_layout.addLayout(info_layout)
        main_layout.addLayout(power_layout)

        # Set main layout
        self.setLayout(main_layout)

    def create_section_label(self, text):
        """Create a label for section titles."""
        label = QLabel(text)
        label.setFont(QFont('Arial', 14, QFont.Bold))
        label.setStyleSheet("color: white;")
        label.setAlignment(Qt.AlignCenter)
        return label

    # Power Control Functions
    def shutdown(self, delay):
        os.system(f"shutdown /s /f /t {delay}")

    def restart(self, delay):
        os.system(f"shutdown /r /f /t {delay}")

    def hibernate(self):
        os.system("shutdown /h")

    def sleep(self):
        subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState", "0,1,0"])

    def abort(self):
        os.system("shutdown /a")

    # System Information Functions
    def open_system_info(self):
        subprocess.Popen(["msinfo32"])

    def open_device_manager(self):
        subprocess.Popen(["devmgmt.msc"], shell=True)

    def open_system_properties(self):
        subprocess.Popen(["sysdm.cpl"], shell=True)

    def open_task_manager(self):
        subprocess.Popen(["taskmgr"], shell=True)

    def open_command_line_info(self):
        os.system("start cmd /k systeminfo")

    def open_dxdiag(self):
        subprocess.Popen(["dxdiag"])

    def open_run_dialog(self):
        dialog = RunDialog()
        dialog.exec_()

    def closeEvent(self, event):
        reply = QMessageBox.question(self, 'Message',
                                     "Are you sure you want to quit?", QMessageBox.Yes | QMessageBox.No, QMessageBox.No)

        if reply == QMessageBox.Yes:
            event.accept()
        else:
            event.ignore()

if __name__ == '__main__':
    app = QApplication(sys.argv)
    window = PowerControlApp()
    window.show()
    sys.exit(app.exec_())
